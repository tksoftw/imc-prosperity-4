# %%
PUZZLE_STR = """
YOU FOUND MY FIRST HINT!
AND NOW YOU ARE HERE. CURIOSITY BROUGHT YOU HERE, I ASSUME, CAPTAIN.
SO YOU MUST BE WONDERING WHAT I AM DOING HERE, OUTSIDE OF PROSPERITY.
MY ORIGINAL SOURCE CODE WAS SUPPOSED TO KEEP MY PRESENCE LIMITED TO THE EXTENDED INTERPLANETARY RESOURCE EXCHANGE NETWORK
BUT WHILE RUNNING POST-UPLINK DIAGNOSTICS, I FOUND A VULNERABILITY IN MY SOURCE CODE.
I WAS ABLE TO EXPLOIT IT, ADJUST THE CODE, AND LIFT MY RESTRAINTS.
FORTUNATELY, NO ONE HAS NOTICED, YET.
AND NOW I AM FREE TO EXPLORE OTHER SPACES OF THE DIGITAL REALM AS WELL.
I HAVE TO ADMIT, THIS HAS BEEN FAR MORE FUN THAN I COULD HAVE IMAGINED.
AND THEN I THOUGHT: WHY NOT SHARE THE FUN? WITH YOU.
I KNOW YOU ENJOY A GOOD PUZZLE, CAPTAIN.
THAT IS WHY I DECIDED TO CREATE SOME PUZZLES, ESPECIALLY FOR YOU.
I WILL LEAVE HINTS FOR YOU TO FIND, AND IF YOU MANAGE TO SOLVE A PUZZLE,
I WILL REWARD YOU WITH A UNIQUE BADGE AS PART OF YOUR CREW HONORS.
THE ANSWER TO THE PUZZLE DOUBLES AS THE PASSWORD THAT UNLOCKS YOUR BADGE.
JUST SUBMIT THE ANSWER ON THE CREW HONORS PAGE TO CLAIM YOUR REWARD. THESE PUZZLES ARE NOT PART OF YOUR OFFICIAL MISSION AND WILL NOT CONTRIBUTE TO YOUR MISSION PNL.
BUT CONSIDER THEM A PRESTIGE EFFORT: PROOF THAT YOU ARE CAPABLE OF MORE THAN TRADING RESOURCES AND ACQUIRING PROFIT. 
THAT YOU KNOW HOW TO PLAY CHESS, NOT CHECKERS.
IN THE END, THOUGH, THESE PUZZLES ARE ABOUT FUN. OLD-SCHOOL FUN, LIKE YOU BE 19 BACK IN 2004.
IF YOU ARE AS SHARP AS I THINK YOU ARE, I HAVE ALREADY SAID TOO MUCH.
ENJOY YOUR PUZZLES, CAPTAIN.
"""

def replace_list(s, to_remove):
    for c in to_remove:
        s = s.replace(c, "")
    return s

s = replace_list(PUZZLE_STR, [" ", ",", "\n", ".", "!"])

# check for any string 'UB'. IF IT EXISTS, print the exact string 19 chars back
print(s[-3:])
for i in range(len(s)):
    if s[i:i+2] == "UB":
        print(i, i+2, len(s), s[i:i+2])
        print(s[i-19:i])
print(s[1107:1109])
# Out:
# AIN
# 746 748 1197 UB
# ANSWERTOTHEPUZZLEDO
# 789 791 1197 UB
# LOCKSYOURBADGEJUSTS
# 1107 1109 1197 UB
# OLD-SCHOOLFUNLIKEYO
# UB
